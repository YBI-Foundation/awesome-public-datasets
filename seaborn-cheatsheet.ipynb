# %% [markdown]
# <a href="https://www.kaggle.com/code/ybifoundation/seaborn-cheatsheet?scriptVersionId=120641756" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # **Seaborn CheatSheet**
